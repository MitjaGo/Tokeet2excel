# %%
import tkinter as tk
from tkinter import *
from tkinter import filedialog
from tkinter.filedialog import askopenfile
import pandas as pd
import numpy as np
import xlsxwriter
    
root = tk.Tk()
root.title("Tokeet2Export")
root.geometry("350x200")

group_number = tk.StringVar()
l0 = tk.Label(root, textvariable=group_number, width=50)
l0.grid(row=3,column=0)

group_number1 = tk.StringVar()
l0 = tk.Label(root, textvariable=group_number1, width=50)
l0.grid(row=6,column=0)

def func(n):
    group_number.set("Izberi gumb: Export " + str())
    

Buttons_A = ["Naloži csv datoteko"]
l2 = tk.Label(root, text = "Odhodi",font=('Helvetica', 12, "bold"), fg='white', bg='#aa8c54', width=20)
l2.grid(row=0, column=0,padx=4,pady=7)

for i in range(len(Buttons_A)):
    btn=tk.Button(root, text=Buttons_A[i], font=('Helvetica', 10), bg='#d8e7ea', width=20, activebackground='#42bed8')
    btn.config(command=lambda:upload_file())
    btn.grid(row=i+1,column=0, padx=4,pady=4)
    
def upload_file():
    
    file = filedialog.askopenfilename(
        initialdir='C:\\Users\\Uporabnik\\Download',
        title='Upload to converter',
        filetypes=[("CSV files", ".csv")])
    
    if file: # user selected one file
        group_number.set(file)
        fob=open(file,'r')
        #print(fob.read())
        df=pd.read_csv(file)
        df['Ura odhoda'] = 0
        df.head()
        df['Plačilo'] = 0
        df.head()
        df['Opombe'] = 0
        df.head()
        #df.replace(0, np.nan, inplace=True)
        df = df[df["Event"].str.contains("Check in")==False]
        vrstice_imena1noc = ['Date','Event','Ura odhoda','Rental','Title','Plačilo','Opombe']
        df = df.reindex(columns=vrstice_imena1noc)
        df.columns = ['Date','Event','Ura_odhoda','Rental','Title','Plačilo','Opombe']
        df = df.sort_values('Rental') 
        
        head = {'Date': '', 'Event': '', 'Ura_odhoda': '', 'Rental': '', 'Title': '', 'Plačilo': '','Opombe': ''}
        head1 = {'Date': '', 'Event': '', 'Ura_odhoda': '', 'Rental': '', 'Title': '', 'Plačilo': '','Opombe': ''}
        dict1 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 1 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict2 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 2 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict3 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 3 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict4 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 4 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict5 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 5 TER','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict6 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 6 TER','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict7 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 7 TER','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict8 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 8 TER','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict9 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'ROOM 9 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict10 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 10 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict11 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 11 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict12 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 12 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict13 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'APP 14 BLK','Title': 'G:','Plačilo': '0','Opombe': '0'}
        dict14 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'ROOM 15 TER','Title':'G:','Plačilo': '0','Opombe': '0'}
        dict15 = {'Date': 'FG odhod', 'Event': 'Check out', 'Ura_odhoda': '0', 'Rental': 'ROOM 16 TER','Title': 'G:','Plačilo': '0','Opombe': '0'}
        
        df = df.append([head, head1, dict1, dict2, dict3, dict4, dict5, dict6, dict7, dict8, dict9, dict10, dict11, dict12, dict13, dict14, dict15,], ignore_index = True)

        df
        
        
        #df.to_excel('C:/Users/Uporabnik/Desktop/Odhodi.xlsx', index=False, header=True)
        
        writer = pd.ExcelWriter('Odhodi-Export.xlsx', engine='xlsxwriter')
        df.to_excel(writer, index=False, sheet_name='Odhodi')
 
        workbook = writer.book
        worksheet = writer.sheets['Odhodi']
    
        worksheet.set_column('A:A', 12)
        worksheet.set_column('B:B', 9)
        worksheet.set_column('C:C', 12)
        worksheet.set_column('D:D', 36)
        worksheet.set_column('E:E', 20)
        worksheet.set_column('F:F', 7)
        worksheet.set_column('G:G', 35)
        
        format0 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        worksheet.conditional_format('C1:C200', {'type':     'text',
        'criteria': 'containing',
        'value':    '0',
        'format':   format0})
        
        format01 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        worksheet.conditional_format('F1:G200', {'type':     'text',
        'criteria': 'containing',
        'value':    '0',
        'format':   format01})
        
        #format02 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        #worksheet.conditional_format('E1:E200', {'type':     'text',
        #'criteria': 'containing',
        #'value':    '$',
        #'format':   format02})
        
           # data with bottom borders
        format1 = workbook.add_format()
        format1.set_top(1)
        format1.set_left(1)
        format1.set_right(1)
        format1.set_bottom(7)

    #snippet added to op script
        format2 = workbook.add_format()
        format2.set_top(2)
        format2.set_bottom(7)

        worksheet.conditional_format(1, 0, 1, df.shape[1] -1,
        {'type': 'cell',
         'criteria': '<>',
         'value': '""',
         'format': format2})
     #end of snippet added to op script

        worksheet.conditional_format(1, 0, df.shape[0], df.shape[1] -1,
        {'type': 'cell',
        'criteria': '<>',
        'value': '""',
        'format': format1}) 
        
        writer.save()
        
Buttons_B_1 = ["Naloži csv datoteko"]


l2 = tk.Label(root, text = "Prihodi",font=('Helvetica', 12, "bold"), fg='white', bg='#aa8c54', width=20)
l2.grid(row=4, column=0,padx=2,pady=4)


for i in range(len(Buttons_B_1)):
    btn=tk.Button(root, text=Buttons_B_1[i], font=('Helvetica', 10), bg='#d8e7ea', width=20, activebackground='#42bed8')
    btn.config(command=lambda:read_file())
    btn.grid(row=i+5,column=0, padx=2,pady=2)
    
def read_file():
    
    file = filedialog.askopenfilename(
        initialdir='C:\\Users\\Uporabnik\\Download',
        title='Upload to converter',
        filetypes=[("CSV files", ".csv")])
    
    if file: # user selected one file 
        group_number1.set(file)
        fob=open(file,'r')
        #print(fob.read())
        df=pd.read_csv(file)
        df['Ura prihoda'] = 0
        df.head()
        df['Vpisan'] = 0
        df.head()
        df['Opombe'] = 0
        df.head()
        df = df[df["Event"].str.contains("Check out")==False]
        vrstice_imena1noc = ['Date','Event','Ura prihoda','Rental','Title','Vpisan','Opombe']
        df = df.reindex(columns=vrstice_imena1noc)
        df.columns = ['Date','Event','Ura_Prihoda','Rental','Title','Vpisan','Opombe']
        df = df.sort_values('Rental')
        
        head = {'Date': '', 'Event': '', 'Ura_Prihoda': '', 'Rental': '', 'Title': '', 'Vpisan': '','Opombe': ''}
        head1 = {'Date': '', 'Event': '', 'Ura_Prihoda': '', 'Rental': '', 'Title': '', 'Vpisan': '','Opombe': ''}
        dict1 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 1 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict2 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 2 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict3 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 3 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict4 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 4 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict5 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 5 TER','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict6 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 6 TER','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict7 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 7 TER','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict8 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 8 TER','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict9 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'ROOM 9 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict10 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 10 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict11 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 11 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict12 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 12 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict13 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'APP 14 BLK','Title': 'G:','Vpisan': '0','Opombe': '0'}
        dict14 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'ROOM 15 TER','Title':'G:','Vpisan': '0','Opombe': '0'}
        dict15 = {'Date': 'FG prihod', 'Event': 'Check in', 'Ura_Prihoda': '0', 'Rental': 'ROOM 16 TER','Title': 'G:','Vpisan': '0','Opombe': '0'}
        
        df = df.append([head, head1, dict1, dict2, dict3, dict4, dict5, dict6, dict7, dict8, dict9, dict10, dict11, dict12, dict13, dict14, dict15,], ignore_index = True)

        df
         
        #df.to_excel('C:/Users/Uporabnik/Desktop/Prihodi.xlsx', index=False, header=True)
        
        writer = pd.ExcelWriter('Prihodi-Export.xlsx', engine='xlsxwriter')
        df.to_excel(writer, index=False, sheet_name='Prihodi')
 
        workbook = writer.book
        worksheet = writer.sheets['Prihodi']
    
        worksheet.set_column('A:A', 12)
        worksheet.set_column('B:B', 9)
        worksheet.set_column('C:C', 12)
        worksheet.set_column('D:D', 36)
        worksheet.set_column('E:E', 20)
        worksheet.set_column('F:F', 7)
        worksheet.set_column('G:G', 35)
                       
        format0 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        worksheet.conditional_format('C1:C200', {'type':     'text',
        'criteria': 'containing',
        'value':    '0',
        'format':   format0})
        
        format01 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        worksheet.conditional_format('F1:G200', {'type':     'text',
        'criteria': 'containing',
        'value':    '0',
        'format':   format01})
        
        #format02 = workbook.add_format({ 'border':1 , 'font_color':'white'})
        
        #worksheet.conditional_format('E1:E200', {'type':     'text',
        #'criteria': 'containing',
        #'value':    '$',
        #'format':   format02})
        
           # data with bottom borders
        format1 = workbook.add_format()
        format1.set_top(1)
        format1.set_left(1)
        format1.set_right(1)
        format1.set_bottom(7)

    #snippet added to op script
        format2 = workbook.add_format()
        format2.set_top(2)
        format2.set_bottom(7)

        worksheet.conditional_format(1, 0, 1, df.shape[1] -1,
        {'type': 'cell',
         'criteria': '<>',
         'value': '""',
         'format': format2})
     #end of snippet added to op script

        worksheet.conditional_format(1, 0, df.shape[0], df.shape[1] -1,
        {'type': 'cell',
        'criteria': '<>',
        'value': '""',
        'format': format1}) 
                
        writer.save()

root.mainloop()
